# %%
SAS_TOKEN = "sp=r&st=2026-03-22T21:46:35Z&se=2026-03-31T06:01:35Z&spr=https&sv=2024-11-04&sr=c&sig=fw5wRG8dhQAmeUf0V9nz5gXOKJ01cyewU5UAH9DxhNk%3D"

SAS_URL = "https://frauddetectionabcbank.blob.core.windows.net/bronze?sp=r&st=2026-03-22T21:46:35Z&se=2026-03-31T06:01:35Z&spr=https&sv=2024-11-04&sr=c&sig=fw5wRG8dhQAmeUf0V9nz5gXOKJ01cyewU5UAH9DxhNk%3D"

ACCOUNT = "frauddetectionabcbank"
CONTAINER = "bronze"

BASE_PATH = f"abfss://{CONTAINER}@{ACCOUNT}.dfs.core.windows.net/"

# %%
transactions_path = f"https://frauddetectionabcbank.blob.core.windows.net/bronze/transactions/transactions_500k.csv?sp=r&st=2026-03-22T21:46:35Z&se=2026-03-31T06:01:35Z&spr=https&sv=2024-11-04&sr=c&sig=fw5wRG8dhQAmeUf0V9nz5gXOKJ01cyewU5UAH9DxhNk%3D"

# %%
customers_path = f"https://frauddetectionabcbank.blob.core.windows.net/bronze/customers/customers_5000.csv?sp=r&st=2026-03-22T21:46:35Z&se=2026-03-31T06:01:35Z&spr=https&sv=2024-11-04&sr=c&sig=fw5wRG8dhQAmeUf0V9nz5gXOKJ01cyewU5UAH9DxhNk%3D"
